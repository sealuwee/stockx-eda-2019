# %% [markdown]
# # Stock X Data Contest for the data nerds
#
# Your submission should consist of a single pdf file with the following items:
#
# 1 chart or graph displaying your results. Do not exceed 1 chart
# A short write-up describing your analysis/results. Do not exceed 200 words
# One entry per participant
# Make sure the pdf has your name and email address somewhere on it
#
# ![StockX image](https://s3.amazonaws.com/stockx-sneaker-analysis/wp-content/uploads/2019/02/StockX_Data-Contest_Logo1-1100x1118.jpg "stockX logo")

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.figure_factory as ff 
from plotly.grid_objs import Grid, Column 
import colorlover as cl

#####################################################
#####################################################

                ##### STOCK X #####
                     # DATA #
                #### CHALLENGE ####
            
#####################################################
#####################################################

path = 'https://s3.amazonaws.com/stockx-sneaker-analysis/wp-content/uploads/2019/02/StockX-Data-Contest-2019.xlsx'

df = pd.read_excel(path, sheet_name=1)

df.head()
# Out:
#   Order Date   Brand                                   Sneaker Name  \
# 0 2017-09-01   Yeezy           Adidas-Yeezy-Boost-350-Low-V2-Beluga
# 1 2017-09-01   Yeezy    Adidas-Yeezy-Boost-350-V2-Core-Black-Copper
# 2 2017-09-01   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-Green
# 3 2017-09-01   Yeezy       Adidas-Yeezy-Boost-350-V2-Core-Black-Red
# 4 2017-09-01   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
#
#    Sale Price  Retail Price Release Date  Shoe Size  Buyer Region
# 0      1097.0           220   2016-09-24       11.0    California
# 1       685.0           220   2016-11-23       11.0    California
# 2       690.0           220   2016-11-23       11.0    California
# 3      1075.0           220   2016-11-23       11.5      Kentucky
# 4       828.0           220   2017-02-11       11.0  Rhode Island

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.corr()
# Out:
#               Sale Price  Retail Price  Shoe Size
# Sale Price      1.000000     -0.361549   0.082795
# Retail Price   -0.361549      1.000000  -0.052798
# Shoe Size       0.082795     -0.052798   1.000000

# %% [markdown]
# ## From the blog post
# The data we’re giving you consists of a random sample of all Off-White x Nike and Yeezy 350 sales from between 9/1/2017 (the month that Off-White first debuted “The Ten” collection) and the present. There are 99,956 total sales in the data set; 27,794 Off-White sales, and 72,162 Yeezy sales. The sample consists of U.S. sales only.
#
# To create this sample, we took a random, fixed percentage of StockX sales (X%) for each colorway, on each day, since September 2017. So, for each day the Off-White Jordan 1 was on the market, we randomly selected X% of its sale from each day. (It’s not important to know what X is; all that matters is that it’s a random sample, and that the same fixed X% of sales was selected from every day, for every sneaker).
#
# We’ve included 8 variables for you to work with: Order Date, Brand, Sneaker Name, Sale Price ($), Retail Price ($), Release Date, Shoe Size, and Buyer State (the U.S. state the buyer shipped to). You can use whatever variables you want in the analysis; you can use 1 variable, or you can use all 8. And remember, every row in the spreadsheet represents an individual StockX sale. There are no averages or order counts; this is just a random sample of daily sales data

# %%
## Creating data frames for yeezys and offwhite shoes

off_white = df.copy()
off_white = off_white[off_white['Brand'].isin(['Off-White'])]

yeezy = df.copy()
yeezy = yeezy[yeezy['Brand'].isin([' Yeezy'])]

print('Shape of Off-White dataframe : {}'.format(off_white.shape))
print('Shape of Yeezy dataframe : {}'.format(yeezy.shape))
# Out:
# Shape of Off-White dataframe : (27794, 8)
# Shape of Yeezy dataframe : (72162, 8)

# %%
#lmao this dataframe is only yeezys and offwhite i dig it
df['Brand'].unique()
# Out:
# array([' Yeezy', 'Off-White'], dtype=object)

# %%
yeezy['Sneaker Name'].unique()
# Out:
# array(['Adidas-Yeezy-Boost-350-Low-V2-Beluga',
#        'Adidas-Yeezy-Boost-350-V2-Core-Black-Copper',
#        'Adidas-Yeezy-Boost-350-V2-Core-Black-Green',
#        'Adidas-Yeezy-Boost-350-V2-Core-Black-Red',
#        'Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017',
#        'Adidas-Yeezy-Boost-350-V2-Core-Black-White',
#        'Adidas-Yeezy-Boost-350-V2-Cream-White',
#        'Adidas-Yeezy-Boost-350-V2-Zebra',
#        'Adidas-Yeezy-Boost-350-Low-Moonrock',
#        'Adidas-Yeezy-Boost-350-Low-Pirate-Black-2016',
#        'Adidas-Yeezy-Boost-350-Low-Oxford-Tan',
#        'Adidas-Yeezy-Boost-350-Low-Turtledove',
#        'Adidas-Yeezy-Boost-350-Low-Pirate-Black-2015',
#        'Adidas-Yeezy-Boost-350-V2-Semi-Frozen-Yellow',
#        'Adidas-Yeezy-Boost-350-V2-Beluga-2pt0',
#        'Adidas-Yeezy-Boost-350-V2-Blue-Tint',
#        'adidas-Yeezy-Boost-350-V2-Butter',
#        'Adidas-Yeezy-Boost-350-V2-Sesame',
#        'adidas-Yeezy-Boost-350-V2-Static',
#        'adidas-Yeezy-Boost-350-V2-Static-Reflective'], dtype=object)

# %%
off_white['Sneaker Name'].unique()
# Out:
# array(['Nike-Air-Max-90-Off-White', 'Nike-Air-Presto-Off-White',
#        'Nike-Air-VaporMax-Off-White',
#        'Air-Jordan-1-Retro-High-Off-White-Chicago',
#        'Nike-Blazer-Mid-Off-White', 'Nike-Air-Force-1-Low-Off-White',
#        'Nike-Air-Max-97-Off-White',
#        'Nike-Air-Force-1-Low-Virgil-Abloh-Off-White-AF100',
#        'Nike-React-Hyperdunk-2017-Flyknit-Off-White',
#        'Nike-Zoom-Fly-Off-White', 'Nike-Air-VaporMax-Off-White-2018',
#        'Air-Jordan-1-Retro-High-Off-White-White',
#        'Nike-Air-VaporMax-Off-White-Black',
#        'Air-Jordan-1-Retro-High-Off-White-University-Blue',
#        'Nike-Air-Presto-Off-White-Black-2018',
#        'Nike-Air-Presto-Off-White-White-2018',
#        'Nike-Zoom-Fly-Mercurial-Off-White-Black',
#        'Nike-Zoom-Fly-Mercurial-Off-White-Total-Orange',
#        'Nike-Air-Max-97-Off-White-Elemental-Rose-Queen',
#        'Nike-Blazer-Mid-Off-White-All-Hallows-Eve',
#        'Nike-Blazer-Mid-Off-White-Grim-Reaper',
#        'Nike-Blazer-Mid-Off-White-Wolf-Grey',
#        'Nike-Air-Max-97-Off-White-Menta',
#        'Nike-Air-Max-97-Off-White-Black',
#        'Nike-Zoom-Fly-Off-White-Black-Silver',
#        'Nike-Zoom-Fly-Off-White-Pink',
#        'Nike-Air-Force-1-Low-Off-White-Volt',
#        'Nike-Air-Force-1-Low-Off-White-Black-White',
#        'Nike-Air-Max-90-Off-White-Black',
#        'Nike-Air-Max-90-Off-White-Desert-Ore'], dtype=object)

# %% [markdown]
# # Ideas for graphs/charts/trends to explore
#
# - Region/Map of where the most buyers are for yeezys vs. offwhite sneakers
# - and what does the this trend ^ explain about the economy in that state or how much disposable income people have to be spending $1,000 on a pair of sneakers LOL
# - Another trend: what sneakers are more popular? Kind of obvious because there are almost 3X as many yeezys sold than offwhite in the entire dataset
# - Another good one would be to look at the difference between resale prices for the shoes?
# - Also how the resale prices change over time
# - Do the shoes appreciate? or do they not?
#
# ## After brainstorming:
#
# - Has 'The Ten' Appreciated or Depreciated in the last year?
# - Have Yeezys gone downhill?

# %%
the_ten = off_white.copy()

the_ten = the_ten[the_ten['Sneaker Name'].isin([
    'Air-Jordan-1-Retro-High-Off-White-Chicago',
    'Nike-Blazer-Mid-Off-White',
    'Nike-Air-VaporMax-Off-White',
    'Nike-Air-Presto-Off-White',
    'Nike-Air-Max-90-Off-White',
    'Nike-Air-Force-1-Low-Off-White',
    'Nike-Air-Max-97-Off-White',
    'Nike-Air-Force-1-Low-Virgil-Abloh-Off-White-AF100',
    'Nike-React-Hyperdunk-2017-Flyknit-Off-White',
    'Nike-Zoom-Fly-Off-White' 
])]
the_ten.head()
# Out:
#     Order Date      Brand                 Sneaker Name  Sale Price  \
# 128 2017-09-07  Off-White    Nike-Air-Max-90-Off-White      1600.0
# 129 2017-09-07  Off-White    Nike-Air-Max-90-Off-White      1090.0
# 130 2017-09-07  Off-White    Nike-Air-Presto-Off-White      1344.0
# 131 2017-09-07  Off-White    Nike-Air-Presto-Off-White      1325.0
# 132 2017-09-07  Off-White  Nike-Air-VaporMax-Off-White      1800.0
#
#      Retail Price Release Date  Shoe Size   Buyer Region
# 128           160   2017-09-09        8.0     California
# 129           160   2017-09-09       11.5       New York
# 130           160   2017-09-09       10.0       New York
# 131           160   2017-09-09       10.0  Massachusetts
# 132           250   2017-09-09       12.0       Kentucky

# %%
the_ten.tail()
# Out:
#       Order Date      Brand                                 Sneaker Name  \
# 99510 2019-02-12  Off-White                      Nike-Zoom-Fly-Off-White
# 99737 2019-02-13  Off-White    Air-Jordan-1-Retro-High-Off-White-Chicago
# 99742 2019-02-13  Off-White               Nike-Air-Force-1-Low-Off-White
# 99842 2019-02-13  Off-White                    Nike-Air-Presto-Off-White
# 99858 2019-02-13  Off-White  Nike-React-Hyperdunk-2017-Flyknit-Off-White
#
#        Sale Price  Retail Price Release Date  Shoe Size Buyer Region
# 99510       821.0           170   2017-11-01       10.0       Oregon
# 99737      2550.0           190   2017-09-09       11.0       Oregon
# 99742      1315.0           170   2017-11-01       11.0   California
# 99842      1700.0           160   2017-09-09       10.0   California
# 99858       767.0           200   2017-11-01       11.0   California

# %% [markdown]
# # Apparently highsnobiety already made an article on the appreciation of Off White sneakers, so i'm going to do something different lmao
#
#
# ## here's a link to it
#
#
# https://www.highsnobiety.com/p/off-white-nike-resell-price-analysis/

# %%
yeezy['Sneaker Name'].value_counts()
# Out:
# adidas-Yeezy-Boost-350-V2-Butter                 11423
# Adidas-Yeezy-Boost-350-V2-Beluga-2pt0            10395
# Adidas-Yeezy-Boost-350-V2-Zebra                  10110
# Adidas-Yeezy-Boost-350-V2-Blue-Tint               9297
# Adidas-Yeezy-Boost-350-V2-Cream-White             9097
# Adidas-Yeezy-Boost-350-V2-Sesame                  5553
# adidas-Yeezy-Boost-350-V2-Static                  4983
# Adidas-Yeezy-Boost-350-V2-Semi-Frozen-Yellow      4854
# adidas-Yeezy-Boost-350-V2-Static-Reflective       3184
# Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017      969
# Adidas-Yeezy-Boost-350-V2-Core-Black-White         621
# Adidas-Yeezy-Boost-350-Low-V2-Beluga               498
# Adidas-Yeezy-Boost-350-V2-Core-Black-Red           302
# Adidas-Yeezy-Boost-350-V2-Core-Black-Copper        225
# Adidas-Yeezy-Boost-350-V2-Core-Black-Green         196
# Adidas-Yeezy-Boost-350-Low-Pirate-Black-2016       122
# Adidas-Yeezy-Boost-350-Low-Moonrock                100
# Adidas-Yeezy-Boost-350-Low-Pirate-Black-2015        95
# Adidas-Yeezy-Boost-350-Low-Oxford-Tan               70
# Adidas-Yeezy-Boost-350-Low-Turtledove               68
# Name: Sneaker Name, dtype: int64

# %%
#gonna do some simple subtraction!
def profit_after_fees(x,y):
    '''
    Taking into account StockX's seller fees at 9.5% maximum and the additional 3% transaction fees.
    Should be 12.5% max 
    https://help.stockx.com/selling-on-stockx/what-are-stockx-selling-fees
    '''
    profit = x - y
    return round((profit * .875),2)

# %%
yeezy['Profit After Fees'] = yeezy.apply(lambda x: profit_after_fees(x['Sale Price'],x['Retail Price']), axis=1)
yeezy.head()
# Out:
#   Order Date   Brand                                   Sneaker Name  \
# 0 2017-09-01   Yeezy           Adidas-Yeezy-Boost-350-Low-V2-Beluga
# 1 2017-09-01   Yeezy    Adidas-Yeezy-Boost-350-V2-Core-Black-Copper
# 2 2017-09-01   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-Green
# 3 2017-09-01   Yeezy       Adidas-Yeezy-Boost-350-V2-Core-Black-Red
# 4 2017-09-01   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
#
#    Sale Price  Retail Price Release Date  Shoe Size  Buyer Region  \
# 0      1097.0           220   2016-09-24       11.0    California
# 1       685.0           220   2016-11-23       11.0    California
# 2       690.0           220   2016-11-23       11.0    California
# 3      1075.0           220   2016-11-23       11.5      Kentucky
# 4       828.0           220   2017-02-11       11.0  Rhode Island
#
#    Profit After Fees
# 0             767.38
# 1             406.88
# 2             411.25
# 3             748.12
# 4             532.00

# %%
##create copy of yeezy where the index is the region?

yeezy_copy = yeezy.copy()
yeezy_copy = yeezy_copy['Buyer Region'].value_counts().reset_index().rename(columns={'index': 'State', 'Buyer Region': 'Total Sales'})
yeezy_copy.head()
# Out:
#         State  Total Sales
# 0  California        13113
# 1    New York        12103
# 2      Oregon         5396
# 3     Florida         4484
# 4       Texas         4455

# %%
### isolate yeezy by region and find average/total profit by state?
### also favorite sneaker by state
# this is some feature engineering here i think

# yeezy_1 = yeezy.groupby('Buyer Region')['Sneaker Name'].apply(set).to_dict()
# yeezy_2 = yeezy.groupby('Buyer Region')['Profit After Fees'].apply(set).to_dict()
test_df = yeezy.drop(columns=['Sale Price','Retail Price','Shoe Size'])
test_df.head()
# Out:
#   Order Date   Brand                                   Sneaker Name  \
# 0 2017-09-01   Yeezy           Adidas-Yeezy-Boost-350-Low-V2-Beluga
# 1 2017-09-01   Yeezy    Adidas-Yeezy-Boost-350-V2-Core-Black-Copper
# 2 2017-09-01   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-Green
# 3 2017-09-01   Yeezy       Adidas-Yeezy-Boost-350-V2-Core-Black-Red
# 4 2017-09-01   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
#
#   Release Date  Buyer Region  Profit After Fees
# 0   2016-09-24    California             767.38
# 1   2016-11-23    California             406.88
# 2   2016-11-23    California             411.25
# 3   2016-11-23      Kentucky             748.12
# 4   2017-02-11  Rhode Island             532.00

# %% [markdown]
# # Create pivot table for State and Yeezy type

# %%
profit_pivot = yeezy.groupby(['Sneaker Name', 'Buyer Region'],as_index=False).sum().pivot('Sneaker Name','Buyer Region','Profit After Fees').fillna(0)
## making one where the states are the index to test
profit_pivot_2 = yeezy.groupby(['Sneaker Name', 'Buyer Region'],as_index=False).sum().pivot('Buyer Region','Sneaker Name','Profit After Fees').fillna(0)
profit_pivot_2.index
# Out:
# Index(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
#        'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan',
#        'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype='object', name='Buyer Region')

# %%
# states = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
#        'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan',
#        'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming']
x = profit_pivot.sum().to_dict()
y = profit_pivot_2.sum().to_dict()
x = sorted(x.items(), key=lambda i: i[1],reverse=True)
yeezy.head()
# Out:
#   Order Date   Brand                                   Sneaker Name  \
# 0 2017-09-01   Yeezy           Adidas-Yeezy-Boost-350-Low-V2-Beluga
# 1 2017-09-01   Yeezy    Adidas-Yeezy-Boost-350-V2-Core-Black-Copper
# 2 2017-09-01   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-Green
# 3 2017-09-01   Yeezy       Adidas-Yeezy-Boost-350-V2-Core-Black-Red
# 4 2017-09-01   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
#
#    Sale Price  Retail Price Release Date  Shoe Size  Buyer Region  \
# 0      1097.0           220   2016-09-24       11.0    California
# 1       685.0           220   2016-11-23       11.0    California
# 2       690.0           220   2016-11-23       11.0    California
# 3      1075.0           220   2016-11-23       11.5      Kentucky
# 4       828.0           220   2017-02-11       11.0  Rhode Island
#
#    Profit After Fees
# 0             767.38
# 1             406.88
# 2             411.25
# 3             748.12
# 4             532.00

# %%
yeezy['Favorite'] = yeezy.groupby(['Buyer Region','Sneaker Name'])['Sneaker Name'].transform('count')

yeezy.head()
# Out:
#   Order Date   Brand                                   Sneaker Name  \
# 0 2017-09-01   Yeezy           Adidas-Yeezy-Boost-350-Low-V2-Beluga
# 1 2017-09-01   Yeezy    Adidas-Yeezy-Boost-350-V2-Core-Black-Copper
# 2 2017-09-01   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-Green
# 3 2017-09-01   Yeezy       Adidas-Yeezy-Boost-350-V2-Core-Black-Red
# 4 2017-09-01   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
#
#    Sale Price  Retail Price Release Date  Shoe Size  Buyer Region  \
# 0      1097.0           220   2016-09-24       11.0    California
# 1       685.0           220   2016-11-23       11.0    California
# 2       690.0           220   2016-11-23       11.0    California
# 3      1075.0           220   2016-11-23       11.5      Kentucky
# 4       828.0           220   2017-02-11       11.0  Rhode Island
#
#    Profit After Fees  Favorite
# 0             767.38       115
# 1             406.88        58
# 2             411.25        58
# 3             748.12         8
# 4             532.00         3

# %%
z = yeezy.groupby(['Buyer Region','Sneaker Name'], as_index=False)['Favorite'].max()
z.head()
# Out:
#   Buyer Region                                  Sneaker Name  Favorite
# 0      Alabama  Adidas-Yeezy-Boost-350-Low-Pirate-Black-2016         1
# 1      Alabama          Adidas-Yeezy-Boost-350-Low-V2-Beluga         4
# 2      Alabama         Adidas-Yeezy-Boost-350-V2-Beluga-2pt0        47
# 3      Alabama           Adidas-Yeezy-Boost-350-V2-Blue-Tint        47
# 4      Alabama      Adidas-Yeezy-Boost-350-V2-Core-Black-Red         1

# %%
xz = z.pivot('Buyer Region','Sneaker Name','Favorite').fillna(0)
xz.head()
# Out:
# Sneaker Name  Adidas-Yeezy-Boost-350-Low-Moonrock  \
# Buyer Region
# Alabama                                       0.0
# Alaska                                        0.0
# Arizona                                       1.0
# Arkansas                                      1.0
# California                                   25.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-Low-Oxford-Tan  \
# Buyer Region
# Alabama                                         0.0
# Alaska                                          0.0
# Arizona                                         0.0
# Arkansas                                        0.0
# California                                     16.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-Low-Pirate-Black-2015  \
# Buyer Region
# Alabama                                                0.0
# Alaska                                                 0.0
# Arizona                                                1.0
# Arkansas                                               0.0
# California                                            28.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-Low-Pirate-Black-2016  \
# Buyer Region
# Alabama                                                1.0
# Alaska                                                 0.0
# Arizona                                                1.0
# Arkansas                                               0.0
# California                                            38.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-Low-Turtledove  \
# Buyer Region
# Alabama                                         0.0
# Alaska                                          0.0
# Arizona                                         1.0
# Arkansas                                        0.0
# California                                     22.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-Low-V2-Beluga  \
# Buyer Region
# Alabama                                        4.0
# Alaska                                         0.0
# Arizona                                        5.0
# Arkansas                                       1.0
# California                                   115.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Beluga-2pt0  \
# Buyer Region
# Alabama                                        47.0
# Alaska                                          4.0
# Arizona                                       147.0
# Arkansas                                       20.0
# California                                   2146.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Blue-Tint  \
# Buyer Region
# Alabama                                      47.0
# Alaska                                        5.0
# Arizona                                     139.0
# Arkansas                                     18.0
# California                                 1682.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Core-Black-Copper  \
# Buyer Region
# Alabama                                               0.0
# Alaska                                                0.0
# Arizona                                               1.0
# Arkansas                                              1.0
# California                                           58.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Core-Black-Green  \
# Buyer Region
# Alabama                                              0.0
# Alaska                                               0.0
# Arizona                                              2.0
# Arkansas                                             0.0
# California                                          58.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Core-Black-Red  \
# Buyer Region
# Alabama                                            1.0
# Alaska                                             1.0
# Arizona                                            2.0
# Arkansas                                           0.0
# California                                        82.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017  \
# Buyer Region
# Alabama                                                 1.0
# Alaska                                                  1.0
# Arizona                                                10.0
# Arkansas                                                2.0
# California                                            250.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Core-Black-White  \
# Buyer Region
# Alabama                                              5.0
# Alaska                                               0.0
# Arizona                                              6.0
# Arkansas                                             1.0
# California                                         142.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Cream-White  \
# Buyer Region
# Alabama                                        51.0
# Alaska                                          9.0
# Arizona                                       152.0
# Arkansas                                       26.0
# California                                   1653.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Semi-Frozen-Yellow  \
# Buyer Region
# Alabama                                               36.0
# Alaska                                                 5.0
# Arizona                                               62.0
# Arkansas                                               7.0
# California                                           587.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Sesame  \
# Buyer Region
# Alabama                                   24.0
# Alaska                                     3.0
# Arizona                                   81.0
# Arkansas                                  10.0
# California                              1045.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Zebra  \
# Buyer Region
# Alabama                                  71.0
# Alaska                                    4.0
# Arizona                                 142.0
# Arkansas                                 12.0
# California                             1737.0
#
# Sneaker Name  adidas-Yeezy-Boost-350-V2-Butter  \
# Buyer Region
# Alabama                                   48.0
# Alaska                                     4.0
# Arizona                                  164.0
# Arkansas                                  26.0
# California                              1810.0
#
# Sneaker Name  adidas-Yeezy-Boost-350-V2-Static  \
# Buyer Region
# Alabama                                   23.0
# Alaska                                     5.0
# Arizona                                   59.0
# Arkansas                                  13.0
# California                               923.0
#
# Sneaker Name  adidas-Yeezy-Boost-350-V2-Static-Reflective
# Buyer Region
# Alabama                                              16.0
# Alaska                                                0.0
# Arizona                                              29.0
# Arkansas                                              3.0
# California                                          696.0

# %%
# favorite_pivot = yeezy.groupby(['Buyer Region', 'Sneaker Name'], as_index=False)..pivot('Sneaker Name','Buyer Region', 'Favorite').fillna(0)
# favorite_pivot
xz['Favorite Sneaker'] = xz[['Adidas-Yeezy-Boost-350-Low-Moonrock',
       'Adidas-Yeezy-Boost-350-Low-Oxford-Tan',
       'Adidas-Yeezy-Boost-350-Low-Pirate-Black-2015',
       'Adidas-Yeezy-Boost-350-Low-Pirate-Black-2016',
       'Adidas-Yeezy-Boost-350-Low-Turtledove',
       'Adidas-Yeezy-Boost-350-Low-V2-Beluga',
       'Adidas-Yeezy-Boost-350-V2-Beluga-2pt0',
       'Adidas-Yeezy-Boost-350-V2-Blue-Tint',
       'Adidas-Yeezy-Boost-350-V2-Core-Black-Copper',
       'Adidas-Yeezy-Boost-350-V2-Core-Black-Green',
       'Adidas-Yeezy-Boost-350-V2-Core-Black-Red',
       'Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017',
       'Adidas-Yeezy-Boost-350-V2-Core-Black-White',
       'Adidas-Yeezy-Boost-350-V2-Cream-White',
       'Adidas-Yeezy-Boost-350-V2-Semi-Frozen-Yellow',
       'Adidas-Yeezy-Boost-350-V2-Sesame', 'Adidas-Yeezy-Boost-350-V2-Zebra',
       'adidas-Yeezy-Boost-350-V2-Butter', 'adidas-Yeezy-Boost-350-V2-Static',
       'adidas-Yeezy-Boost-350-V2-Static-Reflective']].max(axis=1)
xz.head()
# Out:
# Sneaker Name  Adidas-Yeezy-Boost-350-Low-Moonrock  \
# Buyer Region
# Alabama                                       0.0
# Alaska                                        0.0
# Arizona                                       1.0
# Arkansas                                      1.0
# California                                   25.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-Low-Oxford-Tan  \
# Buyer Region
# Alabama                                         0.0
# Alaska                                          0.0
# Arizona                                         0.0
# Arkansas                                        0.0
# California                                     16.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-Low-Pirate-Black-2015  \
# Buyer Region
# Alabama                                                0.0
# Alaska                                                 0.0
# Arizona                                                1.0
# Arkansas                                               0.0
# California                                            28.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-Low-Pirate-Black-2016  \
# Buyer Region
# Alabama                                                1.0
# Alaska                                                 0.0
# Arizona                                                1.0
# Arkansas                                               0.0
# California                                            38.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-Low-Turtledove  \
# Buyer Region
# Alabama                                         0.0
# Alaska                                          0.0
# Arizona                                         1.0
# Arkansas                                        0.0
# California                                     22.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-Low-V2-Beluga  \
# Buyer Region
# Alabama                                        4.0
# Alaska                                         0.0
# Arizona                                        5.0
# Arkansas                                       1.0
# California                                   115.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Beluga-2pt0  \
# Buyer Region
# Alabama                                        47.0
# Alaska                                          4.0
# Arizona                                       147.0
# Arkansas                                       20.0
# California                                   2146.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Blue-Tint  \
# Buyer Region
# Alabama                                      47.0
# Alaska                                        5.0
# Arizona                                     139.0
# Arkansas                                     18.0
# California                                 1682.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Core-Black-Copper  \
# Buyer Region
# Alabama                                               0.0
# Alaska                                                0.0
# Arizona                                               1.0
# Arkansas                                              1.0
# California                                           58.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Core-Black-Green        ...         \
# Buyer Region                                                    ...
# Alabama                                              0.0        ...
# Alaska                                               0.0        ...
# Arizona                                              2.0        ...
# Arkansas                                             0.0        ...
# California                                          58.0        ...
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017  \
# Buyer Region
# Alabama                                                 1.0
# Alaska                                                  1.0
# Arizona                                                10.0
# Arkansas                                                2.0
# California                                            250.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Core-Black-White  \
# Buyer Region
# Alabama                                              5.0
# Alaska                                               0.0
# Arizona                                              6.0
# Arkansas                                             1.0
# California                                         142.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Cream-White  \
# Buyer Region
# Alabama                                        51.0
# Alaska                                          9.0
# Arizona                                       152.0
# Arkansas                                       26.0
# California                                   1653.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Semi-Frozen-Yellow  \
# Buyer Region
# Alabama                                               36.0
# Alaska                                                 5.0
# Arizona                                               62.0
# Arkansas                                               7.0
# California                                           587.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Sesame  \
# Buyer Region
# Alabama                                   24.0
# Alaska                                     3.0
# Arizona                                   81.0
# Arkansas                                  10.0
# California                              1045.0
#
# Sneaker Name  Adidas-Yeezy-Boost-350-V2-Zebra  \
# Buyer Region
# Alabama                                  71.0
# Alaska                                    4.0
# Arizona                                 142.0
# Arkansas                                 12.0
# California                             1737.0
#
# Sneaker Name  adidas-Yeezy-Boost-350-V2-Butter  \
# Buyer Region
# Alabama                                   48.0
# Alaska                                     4.0
# Arizona                                  164.0
# Arkansas                                  26.0
# California                              1810.0
#
# Sneaker Name  adidas-Yeezy-Boost-350-V2-Static  \
# Buyer Region
# Alabama                                   23.0
# Alaska                                     5.0
# Arizona                                   59.0
# Arkansas                                  13.0
# California                               923.0
#
# Sneaker Name  adidas-Yeezy-Boost-350-V2-Static-Reflective  Favorite Sneaker
# Buyer Region
# Alabama                                              16.0              71.0
# Alaska                                                0.0               9.0
# Arizona                                              29.0             164.0
# Arkansas                                              3.0              26.0
# California                                          696.0            2146.0
#
# [5 rows x 21 columns]

# %%
l = []
for i in range(0,len(xz)):
    p = (xz == xz['Favorite Sneaker'][i]).idxmax(axis=1)[i]
    l.append(p)

new_df = pd.DataFrame(l,columns={'Sneaker'})
new_df.head()
new_df['State'] = xz.index
new_df.head()
# Out:
#                                  Sneaker       State
# 0        Adidas-Yeezy-Boost-350-V2-Zebra     Alabama
# 1  Adidas-Yeezy-Boost-350-V2-Cream-White      Alaska
# 2       adidas-Yeezy-Boost-350-V2-Butter     Arizona
# 3  Adidas-Yeezy-Boost-350-V2-Cream-White    Arkansas
# 4  Adidas-Yeezy-Boost-350-V2-Beluga-2pt0  California

# %%
test = pd.DataFrame(data = x,columns=['State','Total Profit']) 
# # test = test.reset_index()
# test = test.rename(columns={'0': 'Total Profit'})
test.head()
# Out:
#         State  Total Profit
# 0  California    1766725.55
# 1    New York    1490796.78
# 2      Oregon     700531.25
# 3     Florida     546883.75
# 4       Texas     506769.39

# %%
yeezy_df = pd.merge(yeezy_copy,test,on='State',sort='True',how='inner')
yeezy_df = pd.merge(yeezy_df, new_df, on='State',sort='True',how='inner')
yeezy_df.head()
### YUHH

yeezy_df
# Out:
#                    State  Total Sales  Total Profit  \
# 0                Alabama          375      43330.01
# 1                 Alaska           41       4070.53
# 2                Arizona         1005     114591.03
# 3               Arkansas          141      15269.69
# 4             California        13113    1766725.55
# 5               Colorado          702      85000.15
# 6            Connecticut          844      91132.07
# 7               Delaware          818     121558.41
# 8   District of Columbia          190      20273.76
# 9                Florida         4484     546883.75
# 10               Georgia         1318     144020.84
# 11                Hawaii          226      32302.33
# 12                 Idaho           84       8929.35
# 13              Illinois         2732     302235.48
# 14               Indiana          787      90573.44
# 15                  Iowa          322      41254.55
# 16                Kansas          275      31156.17
# 17              Kentucky          397      63215.18
# 18             Louisiana          409      41564.16
# 19                 Maine          109       9712.52
# 20              Maryland         1344     155901.37
# 21         Massachusetts         2189     254860.29
# 22              Michigan         2209     262261.27
# 23             Minnesota          526      64064.78
# 24           Mississippi          132      13525.58
# 25              Missouri          511      62168.82
# 26               Montana           41       4801.98
# 27              Nebraska          201      21709.04
# 28                Nevada          541      75332.31
# 29         New Hampshire          182      19795.14
# 30            New Jersey         3371     405882.89
# 31            New Mexico          179      20438.25
# 32              New York        12103    1490796.78
# 33        North Carolina          998     108610.24
# 34          North Dakota           49       5310.02
# 35                  Ohio         1386     156407.99
# 36              Oklahoma          296      35806.05
# 37                Oregon         5396     700531.25
# 38          Pennsylvania         2396     273195.05
# 39          Rhode Island          261      29239.58
# 40        South Carolina          420      46715.28
# 41          South Dakota           50       6445.25
# 42             Tennessee          564      64985.32
# 43                 Texas         4455     506769.39
# 44                  Utah          310      38393.17
# 45               Vermont           55       6926.50
# 46              Virginia         1453     183486.73
# 47            Washington         1362     169006.49
# 48         West Virginia          141      14439.27
# 49             Wisconsin          630      74260.19
# 50               Wyoming           39       3999.61
#
#                                         Sneaker
# 0               Adidas-Yeezy-Boost-350-V2-Zebra
# 1         Adidas-Yeezy-Boost-350-V2-Cream-White
# 2              adidas-Yeezy-Boost-350-V2-Butter
# 3         Adidas-Yeezy-Boost-350-V2-Cream-White
# 4         Adidas-Yeezy-Boost-350-V2-Beluga-2pt0
# 5              adidas-Yeezy-Boost-350-V2-Butter
# 6               Adidas-Yeezy-Boost-350-V2-Zebra
'TX',
'UT',
'VT',
'VA',
'WA',
'WV',
'WI',
'WY']
ids_l = pd.DataFrame(ids,columns={'IDs'})
ids_l.head()
# Out:
#   IDs
# 0  AL
# 1  AK
# 2  AZ
# 3  AR
# 4  CA

# %%
ids_l['State'] = xz.index
ids_l.head()
yeezy_df = pd.merge(yeezy_df,ids_l, on='State', how='inner', sort=True)
yeezy_df.head()
# Out:
#         State  Total Sales  Total Profit  \
# 0     Alabama          375      43330.01
# 1      Alaska           41       4070.53
# 2     Arizona         1005     114591.03
# 3    Arkansas          141      15269.69
# 4  California        13113    1766725.55
#
#                                  Sneaker IDs
# 0        Adidas-Yeezy-Boost-350-V2-Zebra  AL
# 1  Adidas-Yeezy-Boost-350-V2-Cream-White  AK
# 2       adidas-Yeezy-Boost-350-V2-Butter  AZ
# 3  Adidas-Yeezy-Boost-350-V2-Cream-White  AR
# 4  Adidas-Yeezy-Boost-350-V2-Beluga-2pt0  CA

# %%
for col in yeezy_df.columns:
    yeezy_df[col] = yeezy_df[col].astype(str)

yeezy_df['text'] = yeezy_df['State'] + '<br>' +\
    'Total Resale Profit : $' + yeezy_df['Total Profit'] + '<br>' +\
    'Favorite Sneaker : ' + yeezy_df['Sneaker']

# %%
#stockX colorscale

colorscale = [
    [0.0, '#D8F3D3'],
    [0.05, '#C4EDBE'],
    [0.1, '#B1E7A8'],
    [0.15, '#9DE193'],
    [0.2, '#8ADC7D'],
    [0.25, '#76D668'],
    [0.3, '#63D052'],
    [0.35, '#4FCA3D'],
    [0.4, '#3CC427'],
    [0.45, '#29BF12'],
    [0.5, '#26AE11'],
    [0.55, '#229D0F'],
    [0.6, '#1E8B0E'],
    [0.65, '#1B7A0C'],
    [0.7, '#17690A'],
    [0.75, '#135709'],
    [0.8, '#0F4607'],
    [0.85, '#163811'],
    [0.9, '#0F250C' ],
    [0.95, '#0C3505'],
    [0.1, '#082304']
]

# greens = cl.scales['9']['seq']['Greens']

greens = [
    [0, 'rgb(247.0, 252.0, 245.0)'],
    [0.125, 'rgb(229.0, 245.0, 224.0)'],
    [0.25, 'rgb(199.0, 233.0, 192.0)'],
    [0.375, 'rgb(161.0, 217.0, 155.0)'],
    [0.5, 'rgb(116.0, 196.0, 118.0)'],
    [0.625, 'rgb(65.0, 171.0, 93.0)'],
    [0.75, 'rgb(35.0, 139.0, 69.0)'],
    [0.875, 'rgb(0,109,44)'],
    [1, 'rgb(0,68,27)'],
]
greens
# Out:
# [[0, 'rgb(247.0, 252.0, 245.0)'],
#  [0.125, 'rgb(229.0, 245.0, 224.0)'],
#  [0.25, 'rgb(199.0, 233.0, 192.0)'],
#  [0.375, 'rgb(161.0, 217.0, 155.0)'],
#  [0.5, 'rgb(116.0, 196.0, 118.0)'],
#  [0.625, 'rgb(65.0, 171.0, 93.0)'],
#  [0.75, 'rgb(35.0, 139.0, 69.0)'],
#  [0.875, 'rgb(0,109,44)'],
#  [1, 'rgb(0,68,27)']]

# %%
data = [dict(
    type = 'choropleth',
    colorscale = greens,
    locations = yeezy_df['IDs'],
    z = yeezy_df['Total Sales'],
    locationmode='USA-states',
    text = yeezy_df['text'],
    marker = dict(
        line=dict(
            color= 'rgb(255,255,255)',
            width=2
        )),
    colorbar= dict(
        title= 'Resold Yeezy\'s by State'
        )
)]

layout = dict(
    title = '2017-2019 Yeezy\'s Resold by State <br>(Hover for details)',
    geo = dict(
        scope = 'usa',
        projection = dict(type='albers usa'),
        showlakes = True,
        lakecolor = 'rgb(255,255,255)',
    ))

fig = dict(data = data, layout=layout)

# py.plot(fig, filename='yeezy_hover_map')

# %%
yeezy_df.head()
dropped_dc = yeezy_df.copy()
dropped_dc = dropped_dc.set_index('IDs')
dropped_dc = dropped_dc.drop(index='DC')
dropped_dc = dropped_dc.reset_index()

# %%
dropped_dc.head()
# Out:
#   IDs       State Total Sales        Total Profit  \
# 0  AL     Alabama         375   43330.00999999999
# 1  AK      Alaska          41  4070.5299999999997
# 2  AZ     Arizona        1005  114591.03000000001
# 3  AR    Arkansas         141  15269.689999999999
# 4  CA  California       13113  1766725.5499999993
#
#                                  Sneaker  \
# 0        Adidas-Yeezy-Boost-350-V2-Zebra
# 1  Adidas-Yeezy-Boost-350-V2-Cream-White
# 2       adidas-Yeezy-Boost-350-V2-Butter
# 3  Adidas-Yeezy-Boost-350-V2-Cream-White
# 4  Adidas-Yeezy-Boost-350-V2-Beluga-2pt0
#
#                                                 text
# 0  Alabama<br>Total Resale Profit : $43330.009999...
# 1  Alaska<br>Total Resale Profit : $4070.52999999...
# 2  Arizona<br>Total Resale Profit : $114591.03000...
# 3  Arkansas<br>Total Resale Profit : $15269.68999...
# 4  California<br>Total Resale Profit : $1766725.5...

# %%
#divide each sales amount by population of State = percapita
#Find yeezys per capita

IDs = dropped_dc['IDs'].values
pops = [
    4887871,
    737438,
    7171646,
    3013825,
    39557045,
    5695564,
    3572665,
    967171,
    21299325,
    10519475,
    1420491,
    1754208,
    12741080,
    6691878,
    3156145,
    2911505,
    4468402,
    4659978,
    1338404,
    6042718,
    6902149,
    9998915,
    5611179,
    2986530,
    6126452,
    1062305,
    1929268,
    3034392,
    1356458,
    9032873,
    2095428,
    19542209,
    10383620,
    760077,
    11689442,
    3943079,
    4190793,
    12807060,
    1057315,
    5084127,
    882235,
    6770010,
    28701845,
    3161105,
    626299,
    8517685,
    7535591,
    1805832,
    5813568,
    577737
]

pops = pd.DataFrame(pops,columns={'Population'})
pops['IDs'] = IDs
pops.head()
# Out:
#    Population IDs
# 0     4887871  AL
# 1      737438  AK
# 2     7171646  AZ
# 3     3013825  AR
# 4    39557045  CA

# %%
yeezy_df = pd.merge(yeezy_df, pops, how='inner', on='IDs')

# %%
yeezy_df.head()
# Out:
#         State Total Sales        Total Profit  \
# 0     Alabama         375   43330.00999999999
# 1      Alaska          41  4070.5299999999997
# 2     Arizona        1005  114591.03000000001
# 3    Arkansas         141  15269.689999999999
# 4  California       13113  1766725.5499999993
#
#                                  Sneaker IDs  \
# 0        Adidas-Yeezy-Boost-350-V2-Zebra  AL
# 1  Adidas-Yeezy-Boost-350-V2-Cream-White  AK
# 2       adidas-Yeezy-Boost-350-V2-Butter  AZ
# 3  Adidas-Yeezy-Boost-350-V2-Cream-White  AR
# 4  Adidas-Yeezy-Boost-350-V2-Beluga-2pt0  CA
#
#                                                 text  Population
# 0  Alabama<br>Total Resale Profit : $43330.009999...     4887871
# 1  Alaska<br>Total Resale Profit : $4070.52999999...      737438
# 2  Arizona<br>Total Resale Profit : $114591.03000...     7171646
# 3  Arkansas<br>Total Resale Profit : $15269.68999...     3013825
# 4  California<br>Total Resale Profit : $1766725.5...    39557045

# %%
yeezy_df['Yeezy Per Capita'] = (yeezy_df['Total Sales'].astype(int) / yeezy_df['Population'].astype(int)) *100000
yeezy_df.head()
# Out:
#         State Total Sales        Total Profit  \
# 0     Alabama         375   43330.00999999999
# 1      Alaska          41  4070.5299999999997
# 2     Arizona        1005  114591.03000000001
# 3    Arkansas         141  15269.689999999999
# 4  California       13113  1766725.5499999993
#
#                                  Sneaker IDs  \
# 0        Adidas-Yeezy-Boost-350-V2-Zebra  AL
# 1  Adidas-Yeezy-Boost-350-V2-Cream-White  AK
# 2       adidas-Yeezy-Boost-350-V2-Butter  AZ
# 3  Adidas-Yeezy-Boost-350-V2-Cream-White  AR
# 4  Adidas-Yeezy-Boost-350-V2-Beluga-2pt0  CA
#
#                                                 text  Population  \
# 0  Alabama<br>Total Resale Profit : $43330.009999...     4887871
# 1  Alaska<br>Total Resale Profit : $4070.52999999...      737438
# 2  Arizona<br>Total Resale Profit : $114591.03000...     7171646
# 3  Arkansas<br>Total Resale Profit : $15269.68999...     3013825
# 4  California<br>Total Resale Profit : $1766725.5...    39557045
#
#    Yeezy Per Capita
# 0          7.672052
# 1          5.559789
# 2         14.013519
# 3          4.678440
# 4         33.149594

# %%
### okay so animating this data...
###we now know how to pack/unpack our data into the totals/favorites for the total duration..
## but what we're trying to do is look for the result year over year
#organize date time into monthly buckets?

# %%
# yeezy['Date'] = dt.datetime.strftime(yeezy['Order Date'])
yeezy.head()
# Out:
#   Order Date   Brand                                   Sneaker Name  \
# 0 2017-09-01   Yeezy           Adidas-Yeezy-Boost-350-Low-V2-Beluga
# 1 2017-09-01   Yeezy    Adidas-Yeezy-Boost-350-V2-Core-Black-Copper
# 2 2017-09-01   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-Green
# 3 2017-09-01   Yeezy       Adidas-Yeezy-Boost-350-V2-Core-Black-Red
# 4 2017-09-01   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
#
#    Sale Price  Retail Price Release Date  Shoe Size  Buyer Region  \
# 0      1097.0           220   2016-09-24       11.0    California
# 1       685.0           220   2016-11-23       11.0    California
# 2       690.0           220   2016-11-23       11.0    California
# 3      1075.0           220   2016-11-23       11.5      Kentucky
# 4       828.0           220   2017-02-11       11.0  Rhode Island
#
#    Profit After Fees  Favorite
# 0             767.38       115
# 1             406.88        58
# 2             411.25        58
# 3             748.12         8
# 4             532.00         3

# %%
months = np.datetime_as_string(yeezy['Order Date'].values,unit='M')
months.shape
yeezy['Order Month'] = months
yeezy['Count'] = np.ones(yeezy.shape[0])
yeezy.head()
# Out:
#   Order Date   Brand                                   Sneaker Name  \
# 0 2017-09-01   Yeezy           Adidas-Yeezy-Boost-350-Low-V2-Beluga
# 1 2017-09-01   Yeezy    Adidas-Yeezy-Boost-350-V2-Core-Black-Copper
# 2 2017-09-01   Yeezy     Adidas-Yeezy-Boost-350-V2-Core-Black-Green
# 3 2017-09-01   Yeezy       Adidas-Yeezy-Boost-350-V2-Core-Black-Red
# 4 2017-09-01   Yeezy  Adidas-Yeezy-Boost-350-V2-Core-Black-Red-2017
#
#    Sale Price  Retail Price Release Date  Shoe Size  Buyer Region  \
# 0      1097.0           220   2016-09-24       11.0    California
# 1       685.0           220   2016-11-23       11.0    California
# 2       690.0           220   2016-11-23       11.0    California
# 3      1075.0           220   2016-11-23       11.5      Kentucky
# 4       828.0           220   2017-02-11       11.0  Rhode Island
#
#    Profit After Fees  Favorite Order Month  Count
# 0             767.38       115     2017-09    1.0
# 1             406.88        58     2017-09    1.0
# 2             411.25        58     2017-09    1.0
# 3             748.12         8     2017-09    1.0
# 4             532.00         3     2017-09    1.0

# %%
monthly_df = yeezy.groupby(['Buyer Region', 'Order Month'], as_index=False).sum().pivot('Buyer Region','Order Month','Count').fillna(0).cumsum(axis=1)
print(monthly_df.shape)
monthly_df.head()
# Out:
# (51, 18)
# Order Month   2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  \
# Buyer Region
# Alabama           6.0      8.0     25.0     51.0     67.0     78.0     84.0
# Alaska            0.0      0.0      1.0      6.0     10.0     10.0     10.0
# Arizona           3.0      9.0     59.0    139.0    196.0    228.0    266.0
# Arkansas          0.0      1.0      6.0     13.0     21.0     23.0     29.0
# California       94.0    206.0    920.0   2266.0   2907.0   3361.0   3762.0
#
# Order Month   2018-04  2018-05  2018-06  2018-07  2018-08  2018-09  2018-10  \
# Buyer Region
# Alabama          96.0    104.0    117.0    134.0    156.0    168.0    184.0
# Alaska           10.0     11.0     12.0     16.0     17.0     19.0     21.0
# Arizona         290.0    316.0    357.0    440.0    487.0    518.0    571.0
# Arkansas         35.0     38.0     42.0     54.0     61.0     68.0     79.0
# California     4044.0   4417.0   4946.0   5966.0   6471.0   6954.0   7634.0
#
# Order Month   2018-11  2018-12  2019-01  2019-02
# Buyer Region
# Alabama         241.0    304.0    352.0    375.0
# Alaska           25.0     37.0     39.0     41.0
# Arizona         703.0    870.0    974.0   1005.0
# Arkansas         95.0    117.0    136.0    141.0
# California     9250.0  10955.0  12526.0  13113.0

# %%
yeezy_monthly = monthly_df.reset_index().rename(columns={'Buyer Region': 'State'})
yeezy_monthly = pd.merge(yeezy_monthly, ids_l, how='inner', on='State')
yeezy_monthly.head()
# Out:
#         State  2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  \
# 0     Alabama      6.0      8.0     25.0     51.0     67.0     78.0     84.0
# 1      Alaska      0.0      0.0      1.0      6.0     10.0     10.0     10.0
# 2     Arizona      3.0      9.0     59.0    139.0    196.0    228.0    266.0
# 3    Arkansas      0.0      1.0      6.0     13.0     21.0     23.0     29.0
# 4  California     94.0    206.0    920.0   2266.0   2907.0   3361.0   3762.0
#
#    2018-04  2018-05  2018-06  2018-07  2018-08  2018-09  2018-10  2018-11  \
# 0     96.0    104.0    117.0    134.0    156.0    168.0    184.0    241.0
# 1     10.0     11.0     12.0     16.0     17.0     19.0     21.0     25.0
# 2    290.0    316.0    357.0    440.0    487.0    518.0    571.0    703.0
# 3     35.0     38.0     42.0     54.0     61.0     68.0     79.0     95.0
# 4   4044.0   4417.0   4946.0   5966.0   6471.0   6954.0   7634.0   9250.0
#
#    2018-12  2019-01  2019-02 IDs
# 0    304.0    352.0    375.0  AL
# 1     37.0     39.0     41.0  AK
# 2    870.0    974.0   1005.0  AZ
# 3    117.0    136.0    141.0  AR
# 4  10955.0  12526.0  13113.0  CA

# %%
yeezy_monthly = yeezy_monthly.set_index(['IDs'])
yeezy_monthly = yeezy_monthly.drop('DC')
print(yeezy_monthly.shape)
yeezy_monthly = yeezy_monthly.reset_index()
yeezy_monthly.head()
# Out:
# (50, 19)
#   IDs       State  2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  \
# 0  AL     Alabama      6.0      8.0     25.0     51.0     67.0     78.0
# 1  AK      Alaska      0.0      0.0      1.0      6.0     10.0     10.0
# 2  AZ     Arizona      3.0      9.0     59.0    139.0    196.0    228.0
# 3  AR    Arkansas      0.0      1.0      6.0     13.0     21.0     23.0
# 4  CA  California     94.0    206.0    920.0   2266.0   2907.0   3361.0
#
#    2018-03  2018-04  2018-05  2018-06  2018-07  2018-08  2018-09  2018-10  \
# 0     84.0     96.0    104.0    117.0    134.0    156.0    168.0    184.0
# 1     10.0     10.0     11.0     12.0     16.0     17.0     19.0     21.0
# 2    266.0    290.0    316.0    357.0    440.0    487.0    518.0    571.0
# 3     29.0     35.0     38.0     42.0     54.0     61.0     68.0     79.0
# 4   3762.0   4044.0   4417.0   4946.0   5966.0   6471.0   6954.0   7634.0
#
#    2018-11  2018-12  2019-01  2019-02
# 0    241.0    304.0    352.0    375.0
# 1     25.0     37.0     39.0     41.0
# 2    703.0    870.0    974.0   1005.0
# 3     95.0    117.0    136.0    141.0
# 4   9250.0  10955.0  12526.0  13113.0

# %%
yeezy_monthly = pd.merge(yeezy_monthly, pops, on='IDs', how='inner')
yeezy_monthly.head()
# Out:
#   IDs       State  2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  \
# 0  AL     Alabama      6.0      8.0     25.0     51.0     67.0     78.0
# 1  AK      Alaska      0.0      0.0      1.0      6.0     10.0     10.0
# 2  AZ     Arizona      3.0      9.0     59.0    139.0    196.0    228.0
# 3  AR    Arkansas      0.0      1.0      6.0     13.0     21.0     23.0
# 4  CA  California     94.0    206.0    920.0   2266.0   2907.0   3361.0
#
#    2018-03  2018-04     ...      2018-06  2018-07  2018-08  2018-09  2018-10  \
# 0     84.0     96.0     ...        117.0    134.0    156.0    168.0    184.0
# 1     10.0     10.0     ...         12.0     16.0     17.0     19.0     21.0
# 2    266.0    290.0     ...        357.0    440.0    487.0    518.0    571.0
# 3     29.0     35.0     ...         42.0     54.0     61.0     68.0     79.0
# 4   3762.0   4044.0     ...       4946.0   5966.0   6471.0   6954.0   7634.0
#
#    2018-11  2018-12  2019-01  2019-02  Population
# 0    241.0    304.0    352.0    375.0     4887871
# 1     25.0     37.0     39.0     41.0      737438
# 2    703.0    870.0    974.0   1005.0     7171646
# 3     95.0    117.0    136.0    141.0     3013825
# 4   9250.0  10955.0  12526.0  13113.0    39557045
#
# [5 rows x 21 columns]

# %%
yeezy_monthly['Yeezys Per Capita'] = (round((yeezy_df['Total Sales'].astype(int) / yeezy_df['Population'].astype(int)*100000)))
yeezy_monthly.head()
# Out:
#   IDs       State  2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  \
# 0  AL     Alabama      6.0      8.0     25.0     51.0     67.0     78.0
# 1  AK      Alaska      0.0      0.0      1.0      6.0     10.0     10.0
# 2  AZ     Arizona      3.0      9.0     59.0    139.0    196.0    228.0
# 3  AR    Arkansas      0.0      1.0      6.0     13.0     21.0     23.0
# 4  CA  California     94.0    206.0    920.0   2266.0   2907.0   3361.0
#
#    2018-03  2018-04        ...          2018-07  2018-08  2018-09  2018-10  \
# 0     84.0     96.0        ...            134.0    156.0    168.0    184.0
# 1     10.0     10.0        ...             16.0     17.0     19.0     21.0
# 2    266.0    290.0        ...            440.0    487.0    518.0    571.0
# 3     29.0     35.0        ...             54.0     61.0     68.0     79.0
# 4   3762.0   4044.0        ...           5966.0   6471.0   6954.0   7634.0
#
#    2018-11  2018-12  2019-01  2019-02  Population  Yeezys Per Capita
# 0    241.0    304.0    352.0    375.0     4887871                8.0
# 1     25.0     37.0     39.0     41.0      737438                6.0
# 2    703.0    870.0    974.0   1005.0     7171646               14.0
# 3     95.0    117.0    136.0    141.0     3013825                5.0
# 4   9250.0  10955.0  12526.0  13113.0    39557045               33.0
#
# [5 rows x 22 columns]

# %%
test_yeezy = yeezy_monthly.drop(columns=['Population','Yeezys Per Capita'])

# %%
#okay for the sake of this example, i think we need to drop some columns?
yeezy_t = test_yeezy.T.reset_index()
yeezy_t.head()
# Out:
#      index        0       1        2         3           4         5  \
# 0      IDs       AL      AK       AZ        AR          CA        CO
# 1    State  Alabama  Alaska  Arizona  Arkansas  California  Colorado
# 2  2017-09        6       0        3         0          94        11
# 3  2017-10        8       0        9         1         206        23
# 4  2017-11       25       1       59         6         920        52
#
#              6         7        8   ...               40         41     42  \
# 0           CT        DE       FL   ...               SD         TN     TX
# 1  Connecticut  Delaware  Florida   ...     South Dakota  Tennessee  Texas
# 2            5         2       35   ...                0          3     41
# 3           14         3       74   ...                0          6     61
# 4           63        21      282   ...                2         34    241
#
#      43       44        45          46             47         48       49
# 0    UT       VT        VA          WA             WV         WI       WY
# 1  Utah  Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming
# 2     0        0        15          12              1          8        1
# 3     0        2        24          31              3         11        1
# 4     9        4       114          99              7         41        2
#
# [5 rows x 51 columns]

# %%
cols = yeezy_monthly.columns

# %%
#okay so the goal is to like show the cummulative sum of all these shoes...
# but like how we gonna do that
#i think we did it...
#at this point i want to refund plotly holy

# months = ['2017-09', '2017-10', '2017-11', '2017-12', '2018-01', '2018-02',
#        '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08',
#        '2018-09', '2018-10', '2018-11', '2018-12', '2019-01', '2019-02']
# ids = []
# for i in yeezy_monthly['IDs']:
#     if i not in ids:
#         ids.append(i)

# print(ids)

# columns = []

# for month in months:
#     for i in ids:
#         yeezys_by_month = yeezy_monthly[yeezy_monthly[month]]
#         for col in yeezy_monthly:
#             col_name = '{i}_{month}_{column}_grid'.format(
#                 i = i, month = month, column = col_name
#             )
#             appended_columns = Column(list(yeezy_monthly),)
#             columns.append()
# months_from_col = set(months)
columns = []

for col in cols: 
    column_name = '{}'.format(col)
    a_columns = Column(list(yeezy_monthly[col]), column_name)
    columns.append(a_columns)

grid1 = Grid(columns)
grid_url = py.grid_ops.upload(grid1,'yeezy_grid_7', auto_open=True)
# grid_url

# this is without the text

# %%
yeezy_monthly['Yeezys Per Capita'] = yeezy_monthly['Yeezys Per Capita'].astype(str)

yeezy_monthly['text'] = yeezy_monthly['State'] + '<br>' +\
    'Yeezys per 100,000 : ' + yeezy_monthly['Yeezys Per Capita'] + '<br>' +\
    'Favorite Sneaker : ' + yeezy_df['Sneaker']

# %%
columns = []
cols = yeezy_monthly.columns
for col in cols: 
    column_name = '{}'.format(col)
    a_columns = Column(list(yeezy_monthly[col]), column_name)
    columns.append(a_columns)

grid2 = Grid(columns)
grid_url = py.grid_ops.upload(grid2,'yeezy_grid_withtext4', auto_open=True)
# grid_url

# %%
figure = {
    'data': [],
    'layout': {},
    'frames': [],
    'config': {'scrollzoom': True}    
}

figure['layout']['title'] = {
    'Yeezys Resold by Month <br> (09/2017 - 02/2019)'
}
figure['layout']['font'] = {
    'font': ''
}

# %%
# this is without the dictionary stuff
# data = [dict(
#     type = 'choropleth',
#     colorscale = greens,
#     locations = yeezy_monthly['IDs'],
#     z = yeezy_monthly['Total Sales'],
#     locationmode='USA-states',
#     text = yeezy_monthly['text'],
#     marker = dict(
#         line=dict(
#             color= 'rgb(255,255,255)',
#             width=2
#         )),
#     colorbar= dict(
#         title= 'Resold Yeezy\'s by State',
#         )
# )]

layout = dict(
    title='Yeezys Resold by Month <br> (09/2017 - 02/2019)',
    font=dict(family='Helvetica'),
    showlegend=True,
    geo = dict(
        scope = 'usa',
        projection = dict(type='albers usa'),
        showlakes = True,
        lakecolor = 'rgb(255,255,255)',
        ),
    updatemenus = [dict(
        type='buttons',
        showactive=False,
        x=0.05,
        y=1,
        xanchor='right',
        yanchor='top',
        pad=dict(t=0,r=10),
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None,
                 dict(fromcurrent=True,
                     frame=dict(
                         duration=200,redraw=True),
                     transition=dict(
                         duration=200, easing='quadratic-in-out')
                     )]
        )]
    )],
)

# %%
sliders = dict(
        active=0,
        x = 0.1,
        y = 0,
        yanchor = 'top',
        xachor = 'left',
        currentvalue = dict(
            font = dict(
                size=20
            ),
            prefix = 'Year - Month: ',
            xanchor='right',
            visible = True,
        ),
        pad = dict(
            b=10,
            t=50
        ),
        transition = dict(
            duration=300,
            easing = 'cubic-in-out'
        ),
        steps = [])

# %%
figure = {
    'data': [],
    'layout': layout,
    'frames': [],   
}

# %%
ids = []
for i in yeezy_monthly['IDs']:
    if i not in ids:
        ids.append(i)
        
months = ['2017-09', '2017-10', '2017-11', '2017-12', '2018-01', '2018-02',
       '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08',
       '2018-09', '2018-10', '2018-11', '2018-12', '2019-01', '2019-02']

# %%
for month in months:
    data_dict = {
        'type': 'choropleth',
        'colorscale': greens,
        'zsrc': grid2.get_column_reference('{}'.format(months[0])),
        'locationssrc': grid2.get_column_reference('IDs'),
        'textsrc': grid2.get_column_reference('text'),
        'locationmode': 'USA-states',
        'marker': {
            'line': {
                'color': 'rgb(255,255,255)',
                'width': 2
            }
        },
        'colorbar': {
            'title': 'Amount of Yeezys Resold in State'
        },
        'name': month[0]}
    figure['data'].append(data_dict)

# %%
for month in months:
    frame = {
            'data': [], 
            'name': str(month)
    }
    for month in months:
        data_dict = {
            'type': 'choropleth',
            'colorscale': greens,
            'zsrc': grid2.get_column_reference('{}'.format(month)),
            'locationssrc': grid2.get_column_reference('IDs'),
            'textsrc': grid2.get_column_reference('text'),
            'locationmode': 'USA-states',
            'marker': {
                'line': {
                    'color': 'rgb(255,255,255)',
                    'width': 2
                }
            },
            'colorbar': {
                'title': 'Amount of Yeezys Resold in State'
            },
            'name': month
        }
        
        frame['data'].append(data_dict)
        
    figure['frames'].append(frame)
    
    slider_step = {'args':[
        [month],
        {'frame': {'duration':300, 'redraw':False},
         'mode': 'immediate',
         'transition': {'duration':300}}
        ],
        'label': month,
        'method':'animate'}
    sliders['steps'].append(slider_step)

figure['layout']['sliders'] = [sliders]

# %%
figure['frames']
# Out:
# [{'data': [{'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:a824b4',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-09'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:60528b',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-10'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:060e35',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-11'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:e9b04c',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-12'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:86b5c5',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-01'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:218737',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-02'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:503dd6',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-03'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:df5e13',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-04'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:9e7f62',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-05'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:94383c',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-06'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:4fa335',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-07'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:c5bc6d',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-08'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:340c95',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-09'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:924b31',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-10'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:64151a',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-11'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:0b0107',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-12'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:984df5',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2019-01'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:157265',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2019-02'}],
#   'name': '2017-09'},
#  {'data': [{'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:a824b4',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-09'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:60528b',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-10'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:060e35',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-11'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:e9b04c',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-12'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:86b5c5',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-01'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:218737',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-02'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:503dd6',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-03'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:df5e13',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-04'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:9e7f62',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-05'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:94383c',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-06'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:4fa335',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-07'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:c5bc6d',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-08'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:340c95',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-09'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:924b31',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-10'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:64151a',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-11'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:0b0107',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-12'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:984df5',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2019-01'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:157265',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2019-02'}],
#   'name': '2017-10'},
#  {'data': [{'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:a824b4',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-09'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:60528b',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-10'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:060e35',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-11'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:e9b04c',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-12'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:86b5c5',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-01'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:218737',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-02'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:503dd6',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-03'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:df5e13',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-04'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:9e7f62',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-05'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:94383c',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-06'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:4fa335',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-07'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:c5bc6d',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-08'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:340c95',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-09'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:924b31',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-10'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:64151a',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-11'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:0b0107',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-12'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:984df5',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2019-01'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:157265',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2019-02'}],
#   'name': '2017-11'},
#  {'data': [{'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:a824b4',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-09'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:60528b',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-10'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:060e35',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-11'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:e9b04c',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-12'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:86b5c5',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-01'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:218737',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-02'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:503dd6',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-03'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:df5e13',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-04'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:9e7f62',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-05'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:94383c',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-06'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:4fa335',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-07'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:c5bc6d',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-08'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:340c95',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-09'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:924b31',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-10'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:64151a',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-11'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:0b0107',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-12'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:984df5',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2019-01'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
# ...
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:340c95',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-09'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:924b31',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-10'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:64151a',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-11'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:0b0107',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-12'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:984df5',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2019-01'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:157265',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2019-02'}],
#   'name': '2019-01'},
#  {'data': [{'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:a824b4',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-09'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:60528b',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-10'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:060e35',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-11'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:e9b04c',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2017-12'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:86b5c5',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-01'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:218737',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-02'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:503dd6',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-03'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:df5e13',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-04'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:9e7f62',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-05'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:94383c',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-06'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:4fa335',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-07'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:c5bc6d',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-08'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:340c95',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-09'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:924b31',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-10'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:64151a',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-11'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:0b0107',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2018-12'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:984df5',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2019-01'},
#    {'type': 'choropleth',
#     'colorscale': [[0, 'rgb(247.0, 252.0, 245.0)'],
#      [0.125, 'rgb(229.0, 245.0, 224.0)'],
#      [0.25, 'rgb(199.0, 233.0, 192.0)'],
#      [0.375, 'rgb(161.0, 217.0, 155.0)'],
#      [0.5, 'rgb(116.0, 196.0, 118.0)'],
#      [0.625, 'rgb(65.0, 171.0, 93.0)'],
#      [0.75, 'rgb(35.0, 139.0, 69.0)'],
#      [0.875, 'rgb(0,109,44)'],
#      [1, 'rgb(0,68,27)']],
#     'zsrc': 'Ruwai:60:157265',
#     'locationssrc': 'Ruwai:60:594a7f',
#     'textsrc': 'Ruwai:60:a448e3',
#     'locationmode': 'USA-states',
#     'marker': {'line': {'color': 'rgb(255,255,255)', 'width': 2}},
#     'colorbar': {'title': 'Amount of Yeezys Resold in State'},
#     'name': '2019-02'}],
#   'name': '2019-02'}]

# %%
# test = py.create_animations(figure,filename='animation_test3')
# test

# %%
cl.scales['11']['div']['RdYlGn']
# Out:
# ['rgb(165,0,38)',
#  'rgb(215,48,39)',
#  'rgb(244,109,67)',
#  'rgb(253,174,97)',
#  'rgb(254,224,139)',
#  'rgb(255,255,191)',
#  'rgb(217,239,139)',
#  'rgb(166,217,106)',
#  'rgb(102,189,99)',
#  'rgb(26,152,80)',
#  'rgb(0,104,55)']

# %%
#colors is an array of arrays
#each array of colors is size=10
#where colors[0] = least intense scale
#and colors[18] = most intense scale

colors = []
template = 'rgb({r},{g},{b})'

rdylgn = [[0,'rgb(165,0,38)'],
 [0.1, 'rgb(215,48,39)'],
 [0.2, 'rgb(244,109,67)'],
 [0.3, 'rgb(253,174,97)'],
 [0.4, 'rgb(254,224,139)'],
 [0.5,'rgb(255,255,191)'],
 [0.6, 'rgb(217,239,139)'],
 [0.7, 'rgb(166,217,106)'],
 [0.8, 'rgb(102,189,99)'],
 [0.9, 'rgb(26,152,80)'],
 [1,'rgb(0,104,55)']]

# %%
scale = [[0,'rgb(165,0,38)'],
 [0.1, 'rgb(215,48,39)'],
 [0.2, 'rgb(244,109,67)'],
 [0.3, 'rgb(253,174,97)'],
 [0.4, 'rgb(254,224,139)'],
 [0.5,'rgb(255,255,191)'],
 [0.6, 'rgb(217,239,139)'],
 [0.7, 'rgb(166,217,106)'],
 [0.8, 'rgb(102,189,99)'],
 [0.9, 'rgb(26,152,80)'],
 [1,'rgb(0,104,55)']]

# %%
x = cl.scales['7']['seq']['YlGnBu']
x20 = cl.to_hsl(cl.interp(x,200))
from IPython.display import HTML
HTML(cl.to_html(x20))
# Out:
# <div style="background-color:hsl(60.0, 100.0%, 90.0%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(61.14572864321608, 98.61306532663316%, 89.69849246231156%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(62.29145728643216, 97.22613065326634%, 89.39698492462311%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(63.437185929648244, 95.8391959798995%, 89.09547738693468%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl
2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08',
       '2018-09', '2018-10', '2018-11', '2018-12', '2019-01', '2019-02']


layout = dict(
    title='<b> # Of Yeezys Resold by State </b> <br> (09/2017 - 02/2019) <br> Interactive Choropleth <br> Hover for Details',
    font=dict(family='Helvetica'),
    showlegend=True,
    geo = dict(
        scope = 'usa',
        projection = dict(type='albers usa'),
        showlakes = True,
        lakecolor = 'rgb(255,255,255)',
        ),
    updatemenus = [dict(
        type='buttons',
        showactive=False,
        x=0.05,
        y=1,
        xanchor='right',
        yanchor='top',
        pad=dict(t=0,r=10),
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None,
                 dict(fromcurrent=True,
                     frame=dict(
                         duration=500,redraw=True),
                     transition=dict(
                         duration=500, easing='elastic-out')
                     )]
        )]
    )],
#     annotations= [dict(
#         visible=True,
#         opacity=0.8,
#         align='middle',
#         showarrow=False,
#         xref='paper',
#         yref='paper',
#         x=0.8,
#         y=0.3,
#         text=text_annotation1,
#         borderpad=50,
#         xanchor = 'right',
#         yanchor = 'bottom',
#     )]
)

figure = {
    'data': [],
    'layout': layout,
    'frames': [],   
}

sliders = dict(
        active=0,
        x = 0.1,
        y = 0,
        yanchor = 'top',
        xachor = 'left',
        currentvalue = dict(
            font = dict(
                size=20
            ),
            prefix = 'Year - Month: ',
            xanchor='right',
            visible = True,
        ),
        pad = dict(
            b=10,
            t=50
        ),
        transition = dict(
            duration=300,
            easing = 'elastic-in-out'
        ),
        steps = [],
        args = [dict(
            transition=dict(duration=500, easing='elastic-in-out')
        )],
        initialValue = months[0],
        plotlycommand = 'animate',
        values = months,
        visible=True
        )

# for month in months:
data_dict = {
    'type': 'choropleth',
    'colorscale': test,
    'zsrc': grid2.get_column_reference('{}'.format(months[0])),
    'locationssrc': grid2.get_column_reference('IDs'),
    'textsrc': grid2.get_column_reference('text'),
    'locationmode': 'USA-states',
    'marker': {
        'line': {
            'color': 'rgb(255,255,255)',
            'width': 2
        }
    },
    'colorbar': {
        'title': {
            'text': '# of Yeezys Resold',
            'font': {
                'size': 30
            }
        },
        'showticksuffix': 'first',
        'ticksuffix': ' Yeezys Resold',
    },
    'name': months[0]}
figure['data'].append(data_dict)

for month in months:
    frame = {
            'data': [], 
            'name': str(month)
    }
#     for month in months:
    data_dict = {
        'type': 'choropleth',
        'colorscale': test,
        'zsrc': grid2.get_column_reference('{}'.format(month)),
        'locationssrc': grid2.get_column_reference('IDs'),
        'textsrc': grid2.get_column_reference('text'),
        'locationmode': 'USA-states',
        'marker': {
            'line': {
                'color': 'rgb(255,255,255)',
                'width': 2
            }
        },
        'colorbar': {
            'title': {
                'text': '# of Yeezys Resold',
                'font': {
                    'size': 30
            }
        },
            'showticksuffix': 'first',
            'ticksuffix': ' Yeezys Resold',
        },
        'name': month
    }

    frame['data'].append(data_dict)
        
    figure['frames'].append(frame)
    
    slider_step = {'args':[
        [month],
        {'frame': {'duration':300, 'redraw':True},
         'mode': 'immediate',
         'transition': {'duration':300}}
        ],
        'label': month,
        'method':'animate'}
    sliders['steps'].append(slider_step)

figure['layout']['sliders'] = [sliders]

# okay = py.create_animations(figure,filename='yeezys_final1')
# okay

# %%
len(figure['frames'])
# Out:
# 18

# %%
yeezy_cap = yeezy.groupby(['Buyer Region', 'Order Month'], as_index=False).sum().pivot('Buyer Region', 'Order Month', 'Count').fillna(0).cumsum(axis=1)
yeezy_cap = yeezy_cap.reset_index().rename(columns={'Buyer Region': 'State'})
yeezy_cap = pd.merge(yeezy_cap, ids_l,how='inner',on='State')
yeezy_cap = yeezy_cap.set_index(['IDs'])
yeezy_cap = yeezy_cap.drop('DC')
yeezy_cap = yeezy_cap.reset_index()
yeezy_cap = pd.merge(yeezy_cap, pops, on='IDs', how='inner')
yeezy_cap.head()
# Out:
#   IDs       State  2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  \
# 0  AL     Alabama      6.0      8.0     25.0     51.0     67.0     78.0
# 1  AK      Alaska      0.0      0.0      1.0      6.0     10.0     10.0
# 2  AZ     Arizona      3.0      9.0     59.0    139.0    196.0    228.0
# 3  AR    Arkansas      0.0      1.0      6.0     13.0     21.0     23.0
# 4  CA  California     94.0    206.0    920.0   2266.0   2907.0   3361.0
#
#    2018-03  2018-04     ...      2018-06  2018-07  2018-08  2018-09  2018-10  \
# 0     84.0     96.0     ...        117.0    134.0    156.0    168.0    184.0
# 1     10.0     10.0     ...         12.0     16.0     17.0     19.0     21.0
# 2    266.0    290.0     ...        357.0    440.0    487.0    518.0    571.0
# 3     29.0     35.0     ...         42.0     54.0     61.0     68.0     79.0
# 4   3762.0   4044.0     ...       4946.0   5966.0   6471.0   6954.0   7634.0
#
#    2018-11  2018-12  2019-01  2019-02  Population
# 0    241.0    304.0    352.0    375.0     4887871
# 1     25.0     37.0     39.0     41.0      737438
# 2    703.0    870.0    974.0   1005.0     7171646
# 3     95.0    117.0    136.0    141.0     3013825
# 4   9250.0  10955.0  12526.0  13113.0    39557045
#
# [5 rows x 21 columns]

# %%
months = ['2017-09', '2017-10', '2017-11', '2017-12', '2018-01', '2018-02',
       '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08',
       '2018-09', '2018-10', '2018-11', '2018-12', '2019-01', '2019-02']

# I want to represent each value as : YEEZYS OWNED PER 100,000 IN STATE
for month in months:
    yeezy_cap[month] = (yeezy_cap[month].divide(yeezy_cap['Population']))
    yeezy_cap[month] = yeezy_cap[month].multiply(100000)
yeezy_cap.head()
# Out:
#   IDs       State   2017-09   2017-10   2017-11   2017-12   2018-01   2018-02  \
# 0  AL     Alabama  0.122753  0.163670  0.511470  1.043399  1.370740  1.595787
# 1  AK      Alaska  0.000000  0.000000  0.135605  0.813628  1.356046  1.356046
# 2  AZ     Arizona  0.041831  0.125494  0.822684  1.938188  2.732985  3.179186
# 3  AR    Arkansas  0.000000  0.033180  0.199083  0.431346  0.696789  0.763150
# 4  CA  California  0.237632  0.520767  2.325755  5.728436  7.348881  8.496590
#
#     2018-03    2018-04     ...        2018-06    2018-07    2018-08  \
# 0  1.718540   1.964045     ...       2.393680   2.741480   3.191574
# 1  1.356046   1.356046     ...       1.627255   2.169674   2.305279
# 2  3.709051   4.043702     ...       4.977937   6.135272   6.790631
# 3  0.962232   1.161315     ...       1.393578   1.791743   2.024006
# 4  9.510316  10.223211     ...      12.503462  15.082016  16.358654
#
#      2018-09    2018-10    2018-11    2018-12    2019-01    2019-02  \
# 0   3.437079   3.764420   4.930572   6.219477   7.201499   7.672052
# 1   2.576488   2.847697   3.390116   5.017371   5.288580   5.559789
# 2   7.222889   7.961910   9.802492  12.131106  13.581262  14.013519
# 3   2.256269   2.621254   3.152141   3.882110   4.512538   4.678440
# 4  17.579675  19.298712  23.383951  27.694182  31.665662  33.149594
#
#    Population
# 0     4887871
# 1      737438
# 2     7171646
# 3     3013825
# 4    39557045
#
# [5 rows x 21 columns]

# %%
for month in months:
    yeezy_cap[month] = round(yeezy_cap[month],1)
yeezy_cap
# Out:
#    IDs           State  2017-09  2017-10  2017-11  2017-12  2018-01  2018-02
# 35      5.4      6.7      7.4      7.5     3943079
# 36     82.7     86.3    109.8    128.8     4190793
# 37     12.4     15.7     18.1     18.7    12807060
# 38     15.5     20.9     23.8     24.7     1057315
# 39      5.2      6.9      8.0      8.3     5084127
# 40      4.5      5.2      5.6      5.7      882235
# 41      5.8      7.4      8.1      8.3     6770010
# 42     10.4     13.4     15.1     15.5    28701845
# 43      7.4      8.8      9.7      9.8     3161105
# 44      7.2      8.1      8.6      8.8      626299
# 45     12.1     14.7     16.5     17.1     8517685
# 46     13.7     16.0     17.6     18.1     7535591
# 47      4.8      6.4      7.6      7.8     1805832
# 48      7.8      9.5     10.6     10.8     5813568
# 49      5.0      5.7      6.1      6.8      577737
#
# [50 rows x 21 columns]

# %%
x = cl.scales['5']['seq']['YlGn']
x100 = cl.to_hsl(cl.interp(x,100))
from IPython.display import HTML
test = convert_colorscale_format(x100)
HTML(cl.to_html(x100))
# Out:
# <div style="background-color:hsl(60.0, 100.0%, 90.0%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(61.131313131313135, 98.38383838383838%, 89.39393939393939%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(62.26262626262626, 96.76767676767676%, 88.78787878787878%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(63.39393939393939, 95.15151515151516%, 88.18181818181819%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(64.52525252525253, 93.53535353535354%, 87.57575757575758%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(65.65656565656566, 91.91919191919192%, 86.96969696969697%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(66.78787878787878, 90.3030303030303%, 86.36363636363636%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(67.91919191919192, 88.68686868686869%, 85.75757575757575%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(69.05050505050505, 87.07070707070707%, 85.15151515151516%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(70.18181818181819, 85.45454545454545%, 84.54545454545455%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(71.31313131313131, 83.83838383838383%, 83.93939393939394%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(72.44444444444444, 82.22222222222223%, 83.33333333333333%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(73.57575757575758, 80.60606060606061%, 82.72727272727272%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(74.70707070707071, 78.98989898989899%, 82.12121212121212%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(75.83838383838383, 77.37373737373737%, 81.51515151515152%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(76.96969696969697, 75.75757575757575%, 80.9090909090909%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(78.1010101010101, 74.14141414141415%, 80.3030303030303%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(79.23232323232324, 72.52525252525253%, 79.6969696969697%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(80.36363636363636, 70.9090909090909%, 79.0909090909091%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(81.4949494949495, 69.2929292929293%, 78.48484848484848%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(82.62626262626263, 67.67676767676767%, 77.87878787878788%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(83.75757575757575, 66.06060606060606%, 77.27272727272727%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(84.88888888888889, 64.44444444444444%, 76.66666666666667%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(86.02020202020202, 62.82828282828283%, 76.06060606060606%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(87.15151515151516, 61.21212121212121%, 75.45454545454545%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></ ...

# %%
##add features to yeezy_cap
# ## it's lit!
# yeezy_cap['Yeezys Per Capita'] = yeezy_monthly['Yeezys Per Capita'].astype(str)
yeezy_cap['Population'] = yeezy_cap['Population'].astype(str)

yeezy_cap['text'] = 'Yeezys Resold per 100,000' + '<br>' +\
     yeezy_cap['State'] + '<br>' +\
    'State Population : ' + yeezy_cap['Population'] + '<br>' +\
    'Favorite Sneaker : ' + yeezy_df['Sneaker']

# %%
columns = []
cols = yeezy_cap.columns
for col in cols: 
    column_name = '{}'.format(col)
    a_columns = Column(list(yeezy_cap[col]), column_name)
    columns.append(a_columns)

grid3 = Grid(columns)
grid_url = py.grid_ops.upload(grid3,'yeezy_grid_final5', auto_open=True)

# %%
months = ['2017-09', '2017-10', '2017-11', '2017-12', '2018-01', '2018-02',
       '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08',
       '2018-09', '2018-10', '2018-11', '2018-12', '2019-01', '2019-02']


layout = dict(
    title='Yeezys Resold Per Capita by State <br> Interactive Choropleth Between <br> (09/2017 - 02/2019) <br> (Hover for Details)',
    font=dict(family='Helvetica',size=15),
    showlegend=True,
    geo = dict(
        scope = 'usa',
        projection = dict(type='albers usa'),
        showlakes = True,
        lakecolor = 'rgb(255,255,255)',
        ),
    updatemenus = [dict(
        type='buttons',
        showactive=False,
        x=0.05,
        y=1,
        xanchor='right',
        yanchor='top',
        pad=dict(t=0,r=10),
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None,
                 dict(fromcurrent=True,
                     frame=dict(
                         duration=500,redraw=True),
                     transition=dict(
                         duration=500, easing='elastic-out')
                     )]
        )]
    )],
)

figure = {
    'data': [],
    'layout': layout,
    'frames': [],   
}

sliders = dict(
        active=0,
        x = 0.1,
        y = 0,
        yanchor = 'top',
        xachor = 'left',
        currentvalue = dict(
            font = dict(
                size=20
            ),
            prefix = 'Year - Month: ',
            xanchor='right',
            visible = True,
        ),
        pad = dict(
            b=10,
            t=50
        ),
        transition = dict(
            duration=300,
            easing = 'elastic-in-out'
        ),
        steps = [],
        args = [dict(
            transition=dict(duration=500, easing='elastic-in-out')
        )],
        initialValue = months[0],
        plotlycommand = 'animate',
        values = months,
        visible=True
        )

# for month in months:
data_dict = {
    'type': 'choropleth',
    'colorscale': test,
    'zsrc': grid3.get_column_reference('{}'.format(months[0])),
    'locationssrc': grid3.get_column_reference('IDs'),
    'textsrc': grid3.get_column_reference('text'),
    'locationmode': 'USA-states',
    'marker': {
        'line': {
            'color': 'rgb(255,255,255)',
            'width': 2
        }
    },
    'colorbar': {
        'title': {
            'text': 'Yeezys Resold Per Capita <br> Per 100,000',
            'font': {
                'size': 20
            }
        },
        'showticksuffix': 'first',
        'ticksuffix': ' Yeezys Resold Per 100,000',
    },
    'name': months[0]}
figure['data'].append(data_dict)

for month in months:
    frame = {
            'data': [], 
            'name': str(month)
    }
#     for month in months:
    data_dict = {
        'type': 'choropleth',
        'colorscale': test,
        'zsrc': grid3.get_column_reference('{}'.format(month)),
        'locationssrc': grid3.get_column_reference('IDs'),
        'textsrc': grid3.get_column_reference('text'),
        'locationmode': 'USA-states',
        'marker': {
            'line': {
                'color': 'rgb(255,255,255)',
                'width': 2
            }
        },
        'colorbar': {
            'title': {
                'text': 'Yeezys Resold Per Capita <br> Per 100,000',
                'font': {
                    'size': 20
            }
        },
            'showticksuffix': 'first',
            'ticksuffix': ' Yeezys Resold Per 100,000',
        },
        'name': month
    }

    frame['data'].append(data_dict)
        
    figure['frames'].append(frame)
    
    slider_step = {'args':[
        [month],
        {'frame': {'duration':300, 'redraw':True},
         'mode': 'immediate',
         'transition': {'duration':300}}
        ],
        'label': month,
        'method':'animate'}
    sliders['steps'].append(slider_step)

figure['layout']['sliders'] = [sliders]

# %%
final = py.create_animations(figure,filename='yeezys_finalWOWZER')
final
# Out:
# 'https://plot.ly/~Ruwai/72/'
